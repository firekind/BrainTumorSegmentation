# %%
# %tensorflow_version 2.x
! pip install tsalib tensorflow-addons SimpleITK flask_ngrok > /dev/null

# %%
import os
os.chdir("/content/drive/My Drive/6th Sem Project/model_server")

# %%
from flask_ngrok import run_with_ngrok
from app import app

# %%
run_with_ngrok(app)
app.run()
# Out:
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# [19-05-2020 11:35:24 INFO]  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [19-05-2020 11:35:26 DEBUG] Starting new HTTP connection (1): localhost:4040
# [19-05-2020 11:35:26 DEBUG] http://localhost:4040 "GET /api/tunnels HTTP/1.1" 200 771
#  * Running on http://9e5bd95e.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# [19-05-2020 11:35:53 INFO] Received request.
# [19-05-2020 11:35:56 INFO] Processing request.
# [19-05-2020 11:35:57 INFO] Network initialized. Pre-processing data...
# [19-05-2020 11:36:00 INFO] Data preprocessed. Beginning forward pass...
# [19-05-2020 11:36:04 INFO] Forward pass complete. Generating results...
# [19-05-2020 11:36:04 INFO] Results saved.
# [19-05-2020 11:36:04 INFO] Sending response...
# [19-05-2020 11:36:04 INFO] 127.0.0.1 - - [19/May/2020 11:36:04] "POST /api/upload HTTP/1.1" 200 -
# [19-05-2020 11:36:04 INFO] Response sent.

# %%
from pathlib import Path
from model_server import process_request

# %%
path = Path("/content/drive/My Drive/6th Sem Project/BrainTumorSegmentation/data/HGG/Brats18_2013_26_1/")
with app.app_context():
  process_request(path)
# Out:
# [19-05-2020 11:55:11 INFO] Processing request.
# [19-05-2020 11:55:11 INFO] Network initialized. Pre-processing data...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-2c51caa1ff13> in <module>()
#       1 path = Path("/content/drive/My Drive/6th Sem Project/BrainTumorSegmentation/data/HGG/Brats18_2013_26_1/")
#       2 with app.app_context():
# ----> 3   process_request(path)
#
# /content/drive/My Drive/6th Sem Project/model_server/model_server/__init__.py in process_request(dir_path, **kwargs)
#      57     data_file_paths: List[bytes]
#      58     seg_file_path: List[bytes]
# ---> 59     data_file_paths, seg_file_path = get_files(dir_path)
#      60
#      61     # preparing data to be used as the base for the final overlay
#
# /content/drive/My Drive/6th Sem Project/model_server/model_server/utils/dataset.py in get_files(parent_dir)
#     112
#     113     # getting the list of files in the directory
# --> 114     files = os.listdir(directory)
#     115
#     116     # filtering out the data files from the list of files in the directory
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/content/drive/My Drive/6th Sem Project/BrainTumorSegmentation/data/HGG/Brats18_2013_26_1'

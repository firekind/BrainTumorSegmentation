# %%
# %tensorflow_version 2.x
! pip install tsalib tensorflow-addons SimpleITK flask_ngrok > /dev/null

# %%
import os
os.chdir("/content/drive/My Drive/6th Sem Project/model_server")

# %%
from flask_ngrok import run_with_ngrok
from app import app

# %%
run_with_ngrok(app)
app.run()
# Out:
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# [18-05-2020 15:35:43 INFO]  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [18-05-2020 15:35:45 DEBUG] Starting new HTTP connection (1): localhost:4040
# [18-05-2020 15:35:45 DEBUG] http://localhost:4040 "GET /api/tunnels HTTP/1.1" 200 771
#  * Running on http://906eb3e0.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# [18-05-2020 15:36:11 INFO] Received request.
# [18-05-2020 15:36:14 INFO] Processing request.
# [18-05-2020 15:36:16 ERROR] Exception on /api/upload [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
# ...

# %%
from pathlib import Path
from model_server import process_request

# %%
path = Path("/content/drive/My Drive/6th Sem Project/BrainTumorSegmentation/data/HGG/Brats18_2013_26_1/")
with app.app_context():
  process_request(path)
# Out:
# [18-05-2020 06:21:19 INFO] Processing request.
# [18-05-2020 06:21:19 INFO] Network initialized. Pre-processing data...
# [18-05-2020 06:21:22 INFO] Data preprocessed. Beginning forward pass...
# [18-05-2020 06:21:23 INFO] Forward pass complete. Generating results...
# [18-05-2020 06:21:23 INFO] Results saved.
# [18-05-2020 06:21:23 DEBUG] Segmentation label file detected. Processing...
# [18-05-2020 06:21:25 DEBUG] Preprocessed segmentation label. Calculating metrics...
# [18-05-2020 06:21:25 DEBUG] decoder acc: 0.82, vae acc: 0.93, decoder loss: -0.82 vae loss: 0.02
